# %%
import pandas as pd
import csv

# %%
dataset = pd.read_csv('dataset_da_allenamento.csv', sep=";")

# %%
dataset.drop(columns='Unnamed: 0', inplace=True)
dataset.replace('5+', 6, inplace = True)
dataset.replace('3+', 4, inplace = True)
dataset = dataset[dataset.Prezzo != 'Affitto\n                                                                                    750/mese\n                                        ']
dataset = dataset[dataset.Prezzo != 'Affitto\n                                                                                    500/mese\n                                        ']
dataset = dataset[dataset.Locali != 'C']
dataset = dataset[dataset.Prezzo != 'prezzo su richiesta']
dataset = dataset[dataset.Superficie != '250, terreno di proprietà 2.000']
dataset = dataset[dataset.Superficie != '100, terreno di proprietà 200']
dataset = dataset[dataset.Superficie != '160, terreno di proprietà 400']
dataset = dataset[dataset.Superficie != '165, terreno di proprietà 450']
dataset = dataset[dataset.Superficie != '105, terreno di proprietà 100']
dataset = dataset[dataset.Superficie != '130, terreno di proprietà 180']
dataset = dataset[dataset.Prezzo != 'Affitto\n                                                                                    450/mese\n                                        ']

# %%
dataset.fillna(value=0, inplace=True)

# %%
dataset.to_csv('dataset_pre_allenamento.csv', sep=';')

# %%
dataset = dataset.merge(pd.get_dummies(dataset['Zona']), left_index=True, right_index=True)
dataset = dataset.merge(pd.get_dummies(dataset['Piano']), left_index=True, right_index=True)
dataset = dataset.merge(pd.get_dummies(dataset['Contratto']), left_index=True, right_index=True)
dataset = dataset.merge(pd.get_dummies(dataset['Tipologia']), left_index=True, right_index=True)
dataset = dataset.merge(pd.get_dummies(dataset['Tipo proprietà']), left_index=True, right_index=True)
dataset = dataset.merge(pd.get_dummies(dataset['Anno di costruzione']), left_index=True, right_index=True)
dataset = dataset.merge(pd.get_dummies(dataset['Stato']), left_index=True, right_index=True)
dataset = dataset.merge(pd.get_dummies(dataset['Riscaldamento']), left_index=True, right_index=True)
dataset = dataset.merge(pd.get_dummies(dataset['Climatizzatore']), left_index=True, right_index=True)
dataset = dataset.merge(pd.get_dummies(dataset['Classe energetica']), left_index=True, right_index=True)
dataset = dataset.merge(pd.get_dummies(dataset['Arredato S/N']), left_index=True, right_index=True)

dataset.drop(columns='Zona', inplace=True)
dataset.drop(columns='Piano_x', inplace=True)
dataset.drop(columns='Contratto', inplace=True)
dataset.drop(columns='Tipologia', inplace=True)
dataset.drop(columns='Tipo proprietà', inplace=True)
dataset.drop(columns='Anno di costruzione', inplace=True)
dataset.drop(columns='Stato', inplace=True)
dataset.drop(columns='Riscaldamento', inplace=True)
dataset.drop(columns='Climatizzatore', inplace=True)
dataset.drop(columns='Classe energetica', inplace=True)
dataset.drop(columns='Arredato S/N', inplace=True)

dataset.fillna(0,inplace=True)

# %%
dataset['Prezzo'] = dataset['Prezzo'].astype(int)
dataset['Superficie'] = dataset['Superficie'].astype(int)
dataset['Locali'] = dataset['Locali'].astype(int)
#dataset['Price'] = (dataset['Prezzo'].astype(int) + dataset['Spese condominio'].astype(int) + dataset['Spese riscaldamento'].astype(int))
dataset.drop(columns= ['Spese condominio', 'Spese riscaldamento'], inplace=True)

# %%
dataset = dataset[dataset['Prezzo']<1000]
indirizzi = dataset['Link annuncio']
dataset.drop(columns= ['Link annuncio'], inplace=True)

# %%
target = dataset['Prezzo']
data = dataset.drop(columns= ['Prezzo'])

# %%
from tpot import TPOTRegressor
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(data.values, target.values,
                                                    train_size=0.75, test_size=0.25)

tpot = TPOTRegressor(generations=50, population_size=20, verbosity=2, max_eval_time_mins=2, n_jobs=4)
tpot.fit(X_train, y_train)
print(tpot.score(X_test, y_test))
tpot.export('tpot_torino_pipeline.py')
# Out:
# HBox(children=(IntProgress(value=0, description='Optimization Progress', max=1020, style=ProgressStyle(descrip…
# Generation 1 - Current best internal CV score: -10787.38040472647
# Generation 2 - Current best internal CV score: -10787.38040472647
# Generation 3 - Current best internal CV score: -10787.38040472647
# Generation 4 - Current best internal CV score: -10787.38040472647
# Generation 5 - Current best internal CV score: -10711.272126335229
# Generation 6 - Current best internal CV score: -10466.03984629311
# Generation 7 - Current best internal CV score: -10466.03984629311
# Generation 8 - Current best internal CV score: -10436.382351105647
# Generation 9 - Current best internal CV score: -10044.67297930243
# Generation 10 - Current best internal CV score: -9969.142245808365
# Generation 11 - Current best internal CV score: -9965.64044056568
# Generation 12 - Current best internal CV score: -9965.64044056568
# Generation 13 - Current best internal CV score: -9557.719206352445
# Generation 14 - Current best internal CV score: -9557.719206352445
# Generation 15 - Current best internal CV score: -9557.719206352445
# Generation 16 - Current best internal CV score: -9532.305682157168
# Generation 17 - Current best internal CV score: -9532.305682157168
# Generation 18 - Current best internal CV score: -9528.767681842688
# Generation 19 - Current best internal CV score: -9446.322043911832
# Generation 20 - Current best internal CV score: -9446.322043911832
# Generation 21 - Current best internal CV score: -9369.603704833538
# Generation 22 - Current best internal CV score: -9369.603704833538
# Generation 23 - Current best internal CV score: -9369.603704833538
# Generation 24 - Current best internal CV score: -9369.603704833538
# Generation 25 - Current best internal CV score: -9369.603704833538
# Generation 26 - Current best internal CV score: -9369.603704833538
# Generation 27 - Current best internal CV score: -9369.603704833538
# Generation 28 - Current best internal CV score: -9369.603704833538
# Generation 29 - Current best internal CV score: -9369.603704833538
# Generation 30 - Current best internal CV score: -9369.045026626132
# Generation 31 - Current best internal CV score: -9369.045026626132
# Generation 32 - Current best internal CV score: -9369.045026626132
# Generation 33 - Current best internal CV score: -9369.045026626132
# Generation 34 - Current best internal CV score: -9369.045026626132
# Generation 35 - Current best internal CV score: -9369.045026626132
# Generation 36 - Current best internal CV score: -9369.045026626132
# Generation 37 - Current best internal CV score: -9369.045026626132
# Generation 38 - Current best internal CV score: -9369.045026626132
# Generation 39 - Current best internal CV score: -9369.045026626132
# Generation 40 - Current best internal CV score: -9369.045026626132
# Generation 41 - Current best internal CV score: -9369.045026626132
# Generation 42 - Current best internal CV score: -9369.045026626132
# Generation 43 - Current best internal CV score: -9369.045026626132
# Generation 44 - Current best internal CV score: -9369.045026626132
# Generation 45 - Current best internal CV score: -9369.045026626132
# Generation 46 - Current best internal CV score: -9369.045026626132
# Generation 47 - Current best internal CV score: -9369.045026626132
# Generation 48 - Current best internal CV score: -9369.045026626132
# Generation 49 - Current best internal CV score: -9369.045026626132
# Generation 50 - Current best internal CV score: -9369.045026626132
#
# Best pipeline: ExtraTreesRegressor(LassoLarsCV(VarianceThreshold(StandardScaler(input_matrix), threshold=0.0001), normalize=False), bootstrap=False, max_features=0.35000000000000003, min_samples_leaf=1, min_samples_split=2, n_estimators=100)
# -8037.150782567384

# %%
import matplotlib.pyplot as plot

# %%
predictions = []
for item in X_test:
    prediction = tpot.predict([item])
    predictions.append(prediction)

flat_list = []
for sublist in predictions:
    for item in sublist:
        flat_list.append(item)
    
ground_trought = y_test

# %%
predictions = []
for item in data.values:
    prediction = tpot.predict([item])
    predictions.append(prediction)

flat_list = []
for sublist in predictions:
    for item in sublist:
        flat_list.append(item)
    
ground_truth = target.values

# %%
confronto = pd.DataFrame()
confronto['ground_truth'] = ground_truth
confronto['predictions'] = flat_list

# %%
plt = confronto.plot(figsize=(25,10))
fig = plt.get_figure()
fig.savefig("risultato.png")
fig.savefig("risultato.svg")

# %%
from scipy.stats.stats import pearsonr

pearsonr(confronto['ground_truth'].values, confronto['predictions'].values)
# Out:
# (0.9639792078173447, 0.0)

# %%
diff = confronto['ground_truth']-confronto['predictions']

# %%
diff.plot(figsize=(25,10))

# %%
import pickle

with open('tpot_faster.pickle','wb') as xx:
    pickle.dump(tpot.fitted_pipeline_,xx)

# %%
import pickle

with open('tpot_faster.pickle', 'rb') as xx:
    model = pickle.load(xx)

# %%
my_dict = list(tpot.evaluated_individuals_.items())

model_scores = pd.DataFrame()
for model in my_dict:
    model_name = model[0]
    model_info = model[1]
    cv_score = model[1].get('internal_cv_score')  # Pull out cv_score as a column (i.e., sortable)
    model_scores = model_scores.append({'model': model_name,
                                        'cv_score': cv_score,
                                        'model_info': model_info,},
                                       ignore_index=True)

model_scores = model_scores.sort_values('cv_score', ascending=False)

# %%
with open('prediction_TPOT.csv', 'w') as myfile:
    wr = csv.writer(myfile)
    wr.writerow(flat_list)

# %% [markdown]
# ## AUTOML

# %%
from sklearn.model_selection import train_test_split
from auto_ml import Predictor
from auto_ml.utils import get_boston_dataset
from auto_ml.utils_models import load_ml_model
from sklearn.model_selection import train_test_split
import pandas as pd


dataset = pd.read_csv('dataset_pre_allenamento.csv', sep=";")
dataset.drop(columns='Unnamed: 0', inplace=True)
dataset.fillna(0, inplace=True)

dataset['Price'] = dataset['Prezzo'].astype(int)
#dataset['Price'] = (dataset['Prezzo'].astype(int) + dataset['Spese condominio'].astype(int) + dataset['Spese riscaldamento'].astype(int))
dataset['Locali'] = dataset['Locali'].astype(int)
dataset = dataset[dataset['Price']<1000]
dataset.to_csv('dataset_minore_1000.csv', sep=';')
dati = dataset.drop(columns= ['Prezzo','Spese condominio', 'Spese riscaldamento'])

column_descriptions = {
    'Price': 'output',
    'Zona':'categorical',
    'Piano':'categorical',
    'Contratto':'categorical',
    'Tipologia':'categorical',
    'Tipo proprietà':'categorical',
    'Anno di costruzione':'categorical',
    'Stato':'categorical',
    'Riscaldamento':'categorical',
    'Climatizzatore':'categorical',
    'Classe energetica':'categorical',
    'Arredato S/N':'categorical'
}

df_train, df_test = train_test_split(dati,train_size=0.75, test_size=0.25)

ml_predictor = Predictor(type_of_estimator='regressor', column_descriptions=column_descriptions)

ml_predictor.train(df_train)

# Score the model on test data
test_score = ml_predictor.score(df_test, df_test.Price)
test_modello = ml_predictor.save()
trained_model = load_ml_model(test_modello)

predictions = trained_model.predict(dati)
#print(predictions)
# Out:
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\externals\six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:144: FutureWarning: The sklearn.metrics.scorer module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.metrics. Anything that cannot be imported from sklearn.metrics is now part of the private API.
#   warnings.warn(message, FutureWarning)
# Welcome to auto_ml! We're about to go through and make sense of your data using machine learning, and give you a production-ready pipeline to get predictions with.
#
# If you have any issues, or new feature ideas, let us know at http://auto.ml
# You are running on version 2.9.10
# Now using the model training_params that you passed in:
# {}
# After overwriting our defaults with your values, here are the final params that will be used to initialize the model:
# {'presort': False, 'learning_rate': 0.1, 'warm_start': True}
# Running basic data cleaning
# could not convert string to float: 'https://www.immobiliare.it/annunci/54723324/'
# could not convert string to float: 'https://www.immobiliare.it/annunci/79313641/'
# could not convert string to float: 'https://www.immobiliare.it/annunci/79133943/'
# could not convert string to float: 'https://www.immobiliare.it/annunci/79486721/'
# could not convert string to float: 'https://www.immobiliare.it/annunci/78572623/'
# could not convert string to float: 'https://www.immobiliare.it/annunci/79286279/'
# could not convert string to float: 'https://www.immobiliare.it/annunci/78909433/'
# could not convert string to float: 'https://www.immobiliare.it/annunci/78977545/'
# could not convert string to float: 'https://www.immobiliare.it/annunci/69153028/'
# could not convert string to float: 'https://www.immobiliare.it/annunci/79335077/'
#
#
# Encountered a column that is not marked as categorical, but is an "object" pandas type, which typically indicates a categorical column.
# The name of this columns is: "Link annuncio"
# Some example features in this column are: ['https://www.immobiliare.it/annunci/78342989/', 'https://www.immobiliare.it/annunci/78314311/', 'https://www.immobiliare.it/annunci/78656925/', 'https://www.immobiliare.it/annunci/52715408/', 'https://www.immobiliare.it/annunci/74809440/']
# If this is a categorical column, please mark it as `Link annuncio: "categorical"` as part of your column_descriptions
# If this is not a categorical column, please consider converting its dtype before passing data into auto_ml
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\auto_ml\utils_data_cleaning.py:151: UserWarning: Consider marking the "Link annuncio" column as categorical
#   warnings.warn('Consider marking the "{}" column as categorical'.format(key))
# Fitting DataFrameVectorizer
# Now using the model training_params that you passed in:
# {}
# After overwriting our defaults with your values, here are the final params that will be used to initialize the model:
# {'presort': False, 'learning_rate': 0.1, 'warm_start': True}
#
#
# ********************************************************************************************
# About to fit the pipeline for the model GradientBoostingRegressor to predict Price
# Started at:
# 2020-03-03 11:00:04
# [1] random_holdout_set_from_training_data's score is: -162.827
# [2] random_holdout_set_from_training_data's score is: -154.757
# [3] random_holdout_set_from_training_data's score is: -147.522
# [4] random_holdout_set_from_training_data's score is: -141.331
# [5] random_holdout_set_from_training_data's score is: -135.762
# [6] random_holdout_set_from_training_data's score is: -131.373
# [7] random_holdout_set_from_training_data's score is: -127.661
# [8] random_holdout_set_from_training_data's score is: -124.114
# [9] random_holdout_set_from_training_data's score is: -121.277
# [10] random_holdout_set_from_training_data's score is: -118.79
# [11] random_holdout_set_from_training_data's score is: -116.319
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# [12] random_holdout_set_from_training_data's score is: -114.556
# [13] random_holdout_set_from_training_data's score is: -112.412
# [14] random_holdout_set_from_training_data's score is: -111.0
# [15] random_holdout_set_from_training_data's score is: -109.159
# [16] random_holdout_set_from_training_data's score is: -107.728
# [17] random_holdout_set_from_training_data's score is: -106.846
# [18] random_holdout_set_from_training_data's score is: -106.128
# [19] random_holdout_set_from_training_data's score is: -105.04
# [20] random_holdout_set_from_training_data's score is: -103.997
# [21] random_holdout_set_from_training_data's score is: -103.463
# [22] random_holdout_set_from_training_data's score is: -103.101
# [23] random_holdout_set_from_training_data's score is: -102.34
# [24] random_holdout_set_from_training_data's score is: -101.528
# [25] random_holdout_set_from_training_data's score is: -101.241
# [26] random_holdout_set_from_training_data's score is: -101.043
# [27] random_holdout_set_from_training_data's score is: -100.747
# [28] random_holdout_set_from_training_data's score is: -100.651
# [29] random_holdout_set_from_training_data's score is: -100.41
# [30] random_holdout_set_from_training_data's score is: -99.79
# [31] random_holdout_set_from_training_data's score is: -99.403
# [32] random_holdout_set_from_training_data's score is: -98.909
# [33] random_holdout_set_from_training_data's score is: -98.556
# [34] random_holdout_set_from_training_data's score is: -98.506
# [35] random_holdout_set_from_training_data's score is: -98.147
# [36] random_holdout_set_from_training_data's score is: -97.653
# [37] random_holdout_set_from_training_data's score is: -97.296
# [38] random_holdout_set_from_training_data's score is: -96.966
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# [39] random_holdout_set_from_training_data's score is: -96.64
# [40] random_holdout_set_from_training_data's score is: -96.499
# [41] random_holdout_set_from_training_data's score is: -96.427
# [42] random_holdout_set_from_training_data's score is: -96.364
# [43] random_holdout_set_from_training_data's score is: -95.842
# [44] random_holdout_set_from_training_data's score is: -95.725
# [45] random_holdout_set_from_training_data's score is: -95.509
# [46] random_holdout_set_from_training_data's score is: -95.463
# [47] random_holdout_set_from_training_data's score is: -94.984
# [48] random_holdout_set_from_training_data's score is: -94.816
# [49] random_holdout_set_from_training_data's score is: -94.76
# [50] random_holdout_set_from_training_data's score is: -94.635
# [52] random_holdout_set_from_training_data's score is: -94.41
# [54] random_holdout_set_from_training_data's score is: -93.876
# [56] random_holdout_set_from_training_data's score is: -93.59
# [58] random_holdout_set_from_training_data's score is: -93.45
# [60] random_holdout_set_from_training_data's score is: -93.21
# [62] random_holdout_set_from_training_data's score is: -93.234
# [64] random_holdout_set_from_training_data's score is: -92.803
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# [66] random_holdout_set_from_training_data's score is: -92.398
# [68] random_holdout_set_from_training_data's score is: -92.27
# [70] random_holdout_set_from_training_data's score is: -92.279
# [72] random_holdout_set_from_training_data's score is: -91.988
# [74] random_holdout_set_from_training_data's score is: -91.856
# [76] random_holdout_set_from_training_data's score is: -92.248
# [78] random_holdout_set_from_training_data's score is: -91.966
# [80] random_holdout_set_from_training_data's score is: -91.974
# [82] random_holdout_set_from_training_data's score is: -91.916
# [84] random_holdout_set_from_training_data's score is: -91.717
# [86] random_holdout_set_from_training_data's score is: -91.58
# [88] random_holdout_set_from_training_data's score is: -91.31
# [90] random_holdout_set_from_training_data's score is: -91.06
# [92] random_holdout_set_from_training_data's score is: -90.935
# [94] random_holdout_set_from_training_data's score is: -91.007
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# [96] random_holdout_set_from_training_data's score is: -90.925
# [98] random_holdout_set_from_training_data's score is: -90.817
# [100] random_holdout_set_from_training_data's score is: -90.765
# [103] random_holdout_set_from_training_data's score is: -90.756
# [106] random_holdout_set_from_training_data's score is: -90.468
# [109] random_holdout_set_from_training_data's score is: -90.455
# [112] random_holdout_set_from_training_data's score is: -90.63
# [115] random_holdout_set_from_training_data's score is: -90.449
# [118] random_holdout_set_from_training_data's score is: -90.302
# [121] random_holdout_set_from_training_data's score is: -90.202
# [124] random_holdout_set_from_training_data's score is: -90.153
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# [127] random_holdout_set_from_training_data's score is: -90.234
# [130] random_holdout_set_from_training_data's score is: -90.11
# [133] random_holdout_set_from_training_data's score is: -89.977
# [136] random_holdout_set_from_training_data's score is: -89.963
# [139] random_holdout_set_from_training_data's score is: -89.87
# [142] random_holdout_set_from_training_data's score is: -89.731
# [145] random_holdout_set_from_training_data's score is: -89.78
# [148] random_holdout_set_from_training_data's score is: -89.91
# [151] random_holdout_set_from_training_data's score is: -89.94
# [154] random_holdout_set_from_training_data's score is: -89.852
# [157] random_holdout_set_from_training_data's score is: -89.86
# [160] random_holdout_set_from_training_data's score is: -89.859
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# [163] random_holdout_set_from_training_data's score is: -89.852
# [166] random_holdout_set_from_training_data's score is: -89.801
# [169] random_holdout_set_from_training_data's score is: -89.708
# [172] random_holdout_set_from_training_data's score is: -89.94
# [175] random_holdout_set_from_training_data's score is: -89.835
# [178] random_holdout_set_from_training_data's score is: -89.726
# [181] random_holdout_set_from_training_data's score is: -89.703
# [184] random_holdout_set_from_training_data's score is: -89.601
# [187] random_holdout_set_from_training_data's score is: -89.509
# [190] random_holdout_set_from_training_data's score is: -89.746
# [193] random_holdout_set_from_training_data's score is: -89.608
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:1342: FutureWarning: The parameter 'presort' is deprecated and has no effect. It will be removed in v0.24. You can suppress this warning by not passing any value to the 'presort' parameter. We also recommend using HistGradientBoosting models instead.
#   FutureWarning)
# ...
# | 48 | Zona=campidoglio                                                 |       0.0013 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 60 | Zona=le-vallette                                                 |       0.0013 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 18 | Anno di costruzione=1970.0                                       |       0.0013 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 58 | Zona=san-salvario                                                |       0.0013 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 94 | Classe energetica=               D                               |       0.0013 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 35 | Contratto=               Affitto, libero                         |       0.0015 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 86 | Riscaldamento=autonomo                                           |       0.0015 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 90 | Classe energetica=               A+                              |       0.0016 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 24 | Anno di costruzione=2013.0                                       |       0.0016 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 53 | Zona=mirafiori-sud                                               |       0.0016 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 63 | Piano=Con                                                        |       0.0017 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 78 | Tipo proprietà=0                                                 |       0.0017 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 64 | Piano=3°                                                         |       0.0018 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 49 | Zona=vanchiglia                                                  |       0.0018 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 61 | Zona=parella                                                     |       0.0019 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 70 | Piano=4°                                                         |       0.0019 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 85 | Riscaldamento=centralizzato                                      |       0.0020 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 23 | Anno di costruzione=2011.0                                       |       0.0021 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 56 | Zona=madonna-di-campagna                                         |       0.0022 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 69 | Piano=Piano                                                      |       0.0022 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# |  6 | Anno di costruzione=1890.0                                       |       0.0022 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 40 | Zona=lucento                                                     |       0.0023 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 42 | Zona=vanchiglietta                                               |       0.0024 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 62 | Piano=1°                                                         |       0.0024 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 71 | Piano=5°                                                         |       0.0024 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 88 | Classe energetica=               E                               |       0.0025 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 16 | Anno di costruzione=1960.0                                       |       0.0025 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 34 | Contratto=               Affitto, transitorio                    |       0.0025 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 39 | Zona=nizza-millefonti                                            |       0.0026 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 95 | Classe energetica=               F                               |       0.0028 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 32 | Contratto=               Affitto, concordato                     |       0.0030 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 79 | Stato=ottimo/ristrutturato                                       |       0.0030 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 29 | Contratto=               Affitto, 3+2                            |       0.0033 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 20 | Anno di costruzione=1980.0                                       |       0.0033 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# |  2 | Anno di costruzione=0.0                                          |       0.0038 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 59 | Zona=barriera-di-lanzo                                           |       0.0041 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 66 | Piano=6°                                                         |       0.0042 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 31 | Contratto=               Affitto                                 |       0.0042 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# |  7 | Anno di costruzione=1900.0                                       |       0.0042 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 15 | Anno di costruzione=1958.0                                       |       0.0045 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 55 | Zona=borgo-vittoria                                              |       0.0045 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# |  5 | Anno di costruzione=1800.0                                       |       0.0046 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 93 | Classe energetica=               B                               |       0.0047 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 51 | Zona=san-donato                                                  |       0.0048 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 21 | Anno di costruzione=2006.0                                       |       0.0049 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 36 | Zona=barriera-di-milano                                          |       0.0054 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 25 | Anno di costruzione=2014.0                                       |       0.0054 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 84 | Riscaldamento=assente                                            |       0.0056 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 83 | Stato=nuovo/incostruzione                                        |       0.0059 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 28 | Contratto=               Affitto, 4+4                            |       0.0065 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 30 | Contratto=               Affitto, studenti (6-36 mesi)           |       0.0071 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# |  1 | Locali                                                           |       0.0072 |   0.4867 |            0.0000 |            0.0000 |    0.0000 |    0.0000 |    0.0000 |    0.0000 |
# | 76 | Tipo proprietà=Parziale proprietà                                |       0.0082 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 44 | Zona=crocetta                                                    |       0.0084 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 98 | Arredato S/N=Non arredato                                        |       0.0086 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 89 | Classe energetica=               C                               |       0.0106 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 92 | Classe energetica=               Non classificabile              |       0.0140 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 99 | Arredato S/N=Arredato                                            |       0.0150 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 33 | Contratto=0                                                      |       0.0181 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 81 | Stato=buono/abitabile                                            |       0.0297 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# | 52 | Zona=centro                                                      |       0.0679 | nan      |          nan      |          nan      |  nan      |  nan      |  nan      |  nan      |
# |  0 | Superficie                                                       |       0.6192 |  12.7727 |          -60.4691 |           63.0529 |   61.4504 |   63.9747 |   58.0218 |   63.1129 |
# +----+------------------------------------------------------------------+--------------+----------+-------------------+-------------------+-----------+-----------+-----------+-----------+
#
#
# *******
# Legend:
# Importance = Feature Importance
#      Explanation: A weighted measure of how much of the variance the model is able to explain is due to this column
# FR_delta = Feature Response Delta Amount
#      Explanation: Amount this column was incremented or decremented by to calculate the feature reponses
# FR_Decrementing = Feature Response From Decrementing Values In This Column By One FR_delta
#      Explanation: Represents how much the predicted output values respond to subtracting one FR_delta amount from every value in this column
# FR_Incrementing = Feature Response From Incrementing Values In This Column By One FR_delta
#      Explanation: Represents how much the predicted output values respond to adding one FR_delta amount to every value in this column
# FRD_MAD = Feature Response From Decrementing- Median Absolute Delta
#      Explanation: Takes the absolute value of all changes in predictions, then takes the median of those. Useful for seeing if decrementing this feature provokes strong changes that are both positive and negative
# FRI_MAD = Feature Response From Incrementing- Median Absolute Delta
#      Explanation: Takes the absolute value of all changes in predictions, then takes the median of those. Useful for seeing if incrementing this feature provokes strong changes that are both positive and negative
# FRD_abs = Feature Response From Decrementing Avg Absolute Change
#      Explanation: What is the average absolute change in predicted output values to subtracting one FR_delta amount to every value in this column. Useful for seeing if output is sensitive to a feature, but not in a uniformly positive or negative way
# FRI_abs = Feature Response From Incrementing Avg Absolute Change
#      Explanation: What is the average absolute change in predicted output values to adding one FR_delta amount to every value in this column. Useful for seeing if output is sensitive to a feature, but not in a uniformly positive or negative way
# *******
# C:\Users\Francesco Manghi\Anaconda3\lib\site-packages\sklearn\base.py:197: FutureWarning: From version 0.24, get_params will raise an AttributeError if a parameter cannot be retrieved as an instance attribute. Previously it would return None.
#   FutureWarning)
# None
#
#
# ***********************************************
# Advanced scoring metrics for the trained regression model on this particular dataset:
#
# Here is the overall RMSE for these predictions:
# 99.51630104641777
#
# Here is the average of the predictions:
# 510.020920457034
#
# Here is the average actual value on this validation set:
# 509.2919254658385
#
# Here is the median prediction:
# 496.6290557988008
#
# Here is the median actual value:
# 470.0
#
# Here is the mean absolute error:
# 73.58220742382582
#
# Here is the median absolute error (robust to outliers):
# 55.32878908431235
#
# Here is the explained variance:
# 0.6874116136750206
#
# Here is the R-squared value:
# 0.687394838896987
# Count of positive differences (prediction > actual):
# 345
# Count of negative differences:
# 299
# Average positive difference:
# 69.35712225401915
# Average negative difference:
# -78.45730569667967
#
#
# ***********************************************
#
#
#
#
# We have saved the trained pipeline to a filed called "auto_ml_saved_pipeline.dill"
# It is saved in the directory:
# C:\Users\Francesco Manghi\Documents\GITHUB\house_scraping_and_regression
# To use it to get predictions, please follow the following flow (adjusting for your own uses as necessary:
#
#
# `from auto_ml.utils_models import load_ml_model
# `trained_ml_pipeline = load_ml_model("auto_ml_saved_pipeline.dill")
# `trained_ml_pipeline.predict(data)`
#
#
# Note that this pickle/dill file can only be loaded in an environment with the same modules installed, and running the same Python version.
# This version of Python is:
# sys.version_info(major=3, minor=7, micro=6, releaselevel='final', serial=0)
#
#
# When passing in new data to get predictions on, columns that were not present (or were not found to be useful) in the training data will be silently ignored.
# It is worthwhile to make sure that you feed in all the most useful data points though, to make sure you can get the highest quality predictions.

# %%
valutazione = pd.DataFrame()
ground_truth = dati['Price'].values
predictions = trained_model.predict(dati)
valutazione['Reale'] = ground_truth
valutazione['predictions'] = predictions
with open('predictions_AUTOML.csv', 'w') as myfile:
    wr = csv.writer(myfile)
    wr.writerow(predictions)

# %%
import matplotlib.pyplot as plot
plt = valutazione.plot(figsize=(25,10))
fig = plt.get_figure()
fig.savefig("risultato_automl.png")
fig.savefig("risultato_automl.svg")

# %%
from scipy.stats.stats import pearsonr

pearsonr(valutazione['Reale'].values, valutazione['predictions'].values)
# Out:
# (0.8990647592792481, 0.0)

# %%
diff = valutazione['Reale']-valutazione['predictions']
print(diff.std())
diff.plot(figsize=(25,10))
# Out:
# 76.79035504368046
