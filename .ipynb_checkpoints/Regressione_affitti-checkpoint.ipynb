# %%
import pandas as pd
import csv

# %%
dataset = pd.read_csv('regression_dataset.csv', sep=";")

# %%
dataset
# Out:
#      Unnamed: 0              contract       district  \
# 0             0       Affitto, Libero         centro
# 1             1               Affitto         centro
# 2             2  Affitto, Transitorio         centro
# 3             3          Affitto, 4+4         centro
# 4             4   Affitto, Concordato         centro
# ..          ...                   ...            ...
# 131         131          Affitto, 3+2  periferia-sud
# 132         132               Affitto  periferia-sud
# 133         133               Affitto  periferia-sud
# 134         134               Affitto  periferia-sud
# 135         135  Affitto, Transitorio  periferia-sud
#
#                                 renting_type surface  locals  floor  \
# 0    Intera proprietà, classe immobile media      61     2.0     5°
# 1    Intera proprietà, classe immobile media      50     1.0     2°
# 2    Intera proprietà, classe immobile media      65     2.0     1°
# 3    Intera proprietà, classe immobile media     117     2.0     1°
# 4    Intera proprietà, classe immobile media      30     1.0     1°
# ..                                       ...     ...     ...    ...
# 131  Intera proprietà, classe immobile media      90     4.0     2°
# 132  Intera proprietà, classe immobile media     100     3.0     2°
# 133  Intera proprietà, classe immobile media      90     3.0     1°
# 134  Intera proprietà, classe immobile media     108     5.0     3°
# 135  Intera proprietà, classe immobile media     190     5.0  Piano
#
#              property_type price  spese condominio  other_expences  \
# 0         Intera proprietà   480              90.0             NaN
# 1         Intera proprietà   500              50.0             NaN
# 2    Classe immobile media   400               NaN             NaN
# 3         Intera proprietà  1500               NaN             NaN
# 4         Intera proprietà   350               NaN             NaN
# ..                     ...   ...               ...             ...
# 131       Intera proprietà   450             150.0             NaN
# 132       Intera proprietà   750             150.0             NaN
# 133                    NaN   850               NaN             NaN
# 134       Intera proprietà   990             125.0             NaN
# 135       Intera proprietà   700               NaN             NaN
#
#      building_year                status  heating air_conditioning  \
# 0           2006.0  ottimo/ristrutturato      NaN         autonomo
# 1              NaN  ottimo/ristrutturato      NaN             None
# 2              NaN       buono/abitabile      NaN             None
# 3              NaN  ottimo/ristrutturato      NaN             None
# 4              NaN       buono/abitabile      NaN             None
# ..             ...                   ...      ...              ...
# 131         1965.0       buono/abitabile      NaN             None
# 132            NaN  ottimo/ristrutturato      NaN             None
# 133            NaN       buono/abitabile      NaN             None
# 134         1980.0       buono/abitabile      NaN             None
# 135         1970.0       buono/abitabile      NaN             None
#
#      energy_certificate  parking_slots  heating_expences heating_system  \
# 0                   NaN            NaN               NaN       autonomo
# 1                   NaN            NaN               NaN       autonomo
# 2                   NaN            NaN               NaN       autonomo
# 3                   NaN            NaN               NaN       autonomo
# 4                   NaN            NaN               NaN       autonomo
# ..                  ...            ...               ...            ...
# 131                 NaN            NaN               NaN  centralizzato
# 132                 NaN            NaN               NaN  centralizzato
# 133                 NaN            NaN               NaN  centralizzato
# 134                 NaN            NaN               NaN  centralizzato
# 135                 NaN            NaN               NaN       autonomo
#
#                                     announce_link
# 0    https://www.immobiliare.it/annunci/84237648/
# 1    https://www.immobiliare.it/annunci/84221326/
# 2    https://www.immobiliare.it/annunci/84228534/
# 3    https://www.immobiliare.it/annunci/84214102/
# 4    https://www.immobiliare.it/annunci/84227778/
# ..                                            ...
# 131  https://www.immobiliare.it/annunci/83583695/
# 132  https://www.immobiliare.it/annunci/75256404/
# 133  https://www.immobiliare.it/annunci/82672391/
# 134  https://www.immobiliare.it/annunci/78403727/
# 135  https://www.immobiliare.it/annunci/77506516/
#
# [136 rows x 20 columns]

# %%
dataset.drop(columns='renting_type', inplace=True)

# %%
dataset.dtypes
# Out:
# Unnamed: 0              int64
# contract               object
# district               object
# surface                object
# locals                float64
# floor                  object
# property_type          object
# price                  object
# spese condominio      float64
# other_expences        float64
# building_year         float64
# status                 object
# heating               float64
# air_conditioning       object
# energy_certificate    float64
# parking_slots         float64
# heating_expences      float64
# heating_system         object
# announce_link          object
# dtype: object

# %%
#dataset.drop(columns='Unnamed: 0', inplace=True)
dataset['floor']= dataset['floor'].str.replace('\W', '')
dataset.replace('5+', 6, inplace = True)
dataset.replace('3+', 4, inplace = True)
dataset = dataset[dataset.price != 'Affitto\n                                                                                    750/mese\n                                        ']
dataset = dataset[dataset.price != 'Affitto\n                                                                                    500/mese\n                                        ']
dataset = dataset[dataset.locals != 'C']
dataset = dataset[dataset.price != 'prezzo su richiesta']
dataset = dataset[dataset.surface != '250, terreno di proprietà 2.000']
dataset = dataset[dataset.surface != '100, terreno di proprietà 200']
dataset = dataset[dataset.surface != '160, terreno di proprietà 400']
dataset = dataset[dataset.surface != '165, terreno di proprietà 450']
dataset = dataset[dataset.surface != '105, terreno di proprietà 100']
dataset = dataset[dataset.surface != '130, terreno di proprietà 180']
dataset = dataset[dataset.price != 'Affitto\n                                                                                    450/mese\n                                        ']
dataset = dataset[dataset.locals != 'c']

# %%
dataset.fillna(value=0, inplace=True)

# %%
dataset.to_csv('before_regression.csv', sep=';')

# %% [markdown]
# ##
# ## PYCARET

# %%
from pycaret.regression import *
import pandas as pd

# %%
dataset = pd.read_csv('before_regression.csv', sep=";")
dataset['floor']= dataset['floor'].str.replace('\W', '')
dataset = dataset[dataset['price']!='Prezzo su richiesta']
dataset.drop(columns='Unnamed: 0', inplace=True)
dataset.fillna(0, inplace=True)

metri = []

for elem in dataset['surface']:
    if len(elem)>3:
        metri.append(elem[0:3])
    else:
        metri.append(elem)
        
dataset['surface'] = metri
dataset['price'] = dataset['price'].astype(int)
#dataset['Price'] = (dataset['Prezzo'].astype(int) + dataset['Spese condominio'].astype(int) + dataset['Spese riscaldamento'].astype(int))
dataset['locals'] = dataset['locals'].astype(int)
dataset['surface'] = dataset['surface'].astype(int)
dataset = dataset[dataset['price']<1000]
dataset.to_csv('dataset_lower_then_1000.csv', sep=';')
dati = dataset.drop(columns= ['spese condominio', 'heating_expences', 'other_expences', 'energy_certificate'])

# %%
exp_reg101 = setup(data = dati.drop(columns=['announce_link', 'Unnamed: 0.1']), target = 'price', categorical_features = ['contract', 'district', 'floor', 'property_type', 'building_year', 'air_conditioning'], numeric_features=['locals','surface'], remove_outliers= False)
# Out:
# <style  type="text/css" >
# </style><table id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row0_col1" class="data row0 col1" >2803</td>
#             </tr>
#             <tr>
#                         <th id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row1_col1" class="data row1 col1" >price</td>
#             </tr>
#             <tr>
#                         <th id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row2_col0" class="data row2 col0" >Original Data</td>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row2_col1" class="data row2 col1" >(124, 13)</td>
#             </tr>
#             <tr>
#                         <th id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row3_col0" class="data row3 col0" >Missing Values</td>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row3_col1" class="data row3 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row4_col0" class="data row4 col0" >Numeric Features</td>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row4_col1" class="data row4 col1" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row5_col0" class="data row5 col0" >Categorical Features</td>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row5_col1" class="data row5 col1" >8</td>
#             </tr>
#             <tr>
#                         <th id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row6_col0" class="data row6 col0" >Ordinal Features</td>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row6_col1" class="data row6 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row7_col0" class="data row7 col0" >High Cardinality Features</td>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row7_col1" class="data row7 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row8_col0" class="data row8 col0" >High Cardinality Method</td>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row8_col1" class="data row8 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row9_col0" class="data row9 col0" >Transformed Train Set</td>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row9_col1" class="data row9 col1" >(86, 57)</td>
#             </tr>
#             <tr>
#                         <th id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row10_col0" class="data row10 col0" >Transformed Test Set</td>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row10_col1" class="data row10 col1" >(38, 57)</td>
#             </tr>
#             <tr>
#                         <th id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row11_col0" class="data row11 col0" >Shuffle Train-Test</td>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row11_col1" class="data row11 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row12_col0" class="data row12 col0" >Stratify Train-Test</td>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row12_col1" class="data row12 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row13_col0" class="data row13 col0" >Fold Generator</td>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row13_col1" class="data row13 col1" >KFold</td>
#             </tr>
#             <tr>
#                         <th id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row14_col0" class="data row14 col0" >Fold Number</td>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row14_col1" class="data row14 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row15_col0" class="data row15 col0" >CPU Jobs</td>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row15_col1" class="data row15 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row16_col0" class="data row16 col0" >Use GPU</td>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row16_col1" class="data row16 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row17_col0" class="data row17 col0" >Log Experiment</td>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row17_col1" class="data row17 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row18_col0" class="data row18 col0" >Experiment Name</td>
#                         <td id="T_75f20a4e_3022_11eb_a8b4_e0b9a5834b53row18_col1" class="data row18 col1" >reg-default-name</td>
#             </tr>
#             <tr>
#                         <t

# %%
compare_models(exclude=['lar'])
# Out:
# <style  type="text/css" >
#     #T_875c0b18_3022_11eb_a8b4_e0b9a5834b53 th {
#           text-align: left;
#     }#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row0_col0,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row0_col1,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row0_col5,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row0_col6,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row1_col0,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row1_col2,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row1_col3,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row1_col4,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row2_col0,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row2_col1,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row2_col2,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row2_col3,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row2_col4,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row2_col5,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row2_col6,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row3_col0,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row3_col1,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row3_col2,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row3_col3,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row3_col4,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row3_col5,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row3_col6,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row4_col0,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row4_col1,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row4_col2,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row4_col3,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row4_col4,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row4_col5,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row4_col6,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row5_col0,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row5_col1,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row5_col2,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row5_col3,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row5_col4,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row5_col5,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row5_col6,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row6_col0,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row6_col1,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row6_col2,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row6_col3,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row6_col4,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row6_col5,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row6_col6,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row7_col0,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row7_col1,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row7_col2,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row7_col3,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row7_col4,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row7_col5,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row7_col6,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row8_col0,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row8_col1,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row8_col2,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row8_col3,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row8_col4,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row8_col5,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row8_col6,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row9_col0,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row9_col1,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row9_col2,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row9_col3,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row9_col4,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row9_col5,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row9_col6,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row10_col0,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row10_col1,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row10_col2,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row10_col3,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row10_col4,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row10_col5,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row10_col6,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row11_col0,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row11_col1,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row11_col2,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row11_col3,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row11_col4,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row11_col5,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row11_col6,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row12_col0,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row12_col1,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row12_col2,#T_875c0b ...
#             text-align:  left;
#             text-align:  left;
#         }#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row0_col2,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row0_col3,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row0_col4,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row1_col1,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row1_col5,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row1_col6{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row0_col7,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row1_col7,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row2_col7,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row3_col7,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row4_col7,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row5_col7,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row6_col7,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row7_col7,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row8_col7,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row9_col7,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row10_col7,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row11_col7,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row12_col7,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row13_col7,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row14_col7,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row15_col7,#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row16_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_875c0b18_3022_11eb_a8b4_e0b9a5834b53row17_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_875c0b18_3022_11eb_a8b4_e0b9a5834b53" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RM
# AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
#                   n_estimators=50, random_state=2803)

# %%
model = create_model('rf')
# Out:
# <style  type="text/css" >
# #T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row10_col0,#T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row10_col1,#T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row10_col2,#T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row10_col3,#T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row10_col4,#T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row10_col5{
#             background:  yellow;
#         }</style><table id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row0_col0" class="data row0 col0" >66.4779</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row0_col1" class="data row0 col1" >6309.4251</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row0_col2" class="data row0 col2" >79.4319</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row0_col3" class="data row0 col3" >0.7337</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row0_col4" class="data row0 col4" >0.1667</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row0_col5" class="data row0 col5" >0.1409</td>
#             </tr>
#             <tr>
#                         <th id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row1_col0" class="data row1 col0" >70.3611</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row1_col1" class="data row1 col1" >6127.7542</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row1_col2" class="data row1 col2" >78.2800</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row1_col3" class="data row1 col3" >0.8091</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row1_col4" class="data row1 col4" >0.1371</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row1_col5" class="data row1 col5" >0.1289</td>
#             </tr>
#             <tr>
#                         <th id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row2_col0" class="data row2 col0" >84.0333</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row2_col1" class="data row2 col1" >13919.6606</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row2_col2" class="data row2 col2" >117.9816</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row2_col3" class="data row2 col3" >0.2768</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row2_col4" class="data row2 col4" >0.1842</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row2_col5" class="data row2 col5" >0.1469</td>
#             </tr>
#             <tr>
#                         <th id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row3_col0" class="data row3 col0" >62.6806</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row3_col1" class="data row3 col1" >4915.4758</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row3_col2" class="data row3 col2" >70.1105</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row3_col3" class="data row3 col3" >0.7329</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row3_col4" class="data row3 col4" >0.1261</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row3_col5" class="data row3 col5" >0.1235</td>
#             </tr>
#             <tr>
#                         <th id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row4_col0" class="data row4 col0" >94.7337</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row4_col1" class="data row4 col1" >15677.5437</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row4_col2" class="data row4 col2" >125.2100</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row4_col3" class="data row4 col3" >0.4586</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row4_col4" class="data row4 col4" >0.2153</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row4_col5" class="data row4 col5" >0.1702</td>
#             </tr>
#             <tr>
#                         <th id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row5_col0" class="data row5 col0" >86.6833</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row5_col1" class="data row5 col1" >11381.3769</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row5_col2" class="data row5 col2" >106.6835</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row5_col3" class="data row5 col3" >0.5480</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row5_col4" class="data row5 col4" >0.1680</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row5_col5" class="data row5 col5" >0.1430</td>
#             </tr>
#             <tr>
#                         <th id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row6_col0" class="data row6 col0" >46.1028</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row6_col1" class="data row6 col1" >4328.0447</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row6_col2" class="data row6 col2" >65.7879</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row6_col3" class="data row6 col3" >0.5757</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row6_col4" class="data row6 col4" >0.1253</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row6_col5" class="data row6 col5" >0.0779</td>
#             </tr>
#             <tr>
#                         <th id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row7_col0" class="data row7 col0" >118.5031</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row7_col1" class="data row7 col1" >36377.1982</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row7_col2" class="data row7 col2" >190.7281</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row7_col3" class="data row7 col3" >-0.0446</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row7_col4" class="data row7 col4" >0.4140</td>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row7_col5" class="data row7 col5" >0.3325</td>
#             </tr>
#             <tr>
#                         <th id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_c4d3a244_3022_11eb_a8b4_e0b9a5834b53row8_col0" class="data row8

# %%
tuned_model = tune_model(model, n_iter = 10)
# Out:
# <style  type="text/css" >
# #T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row10_col0,#T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row10_col1,#T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row10_col2,#T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row10_col3,#T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row10_col4,#T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row10_col5{
#             background:  yellow;
#         }</style><table id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >MAE</th>        <th class="col_heading level0 col1" >MSE</th>        <th class="col_heading level0 col2" >RMSE</th>        <th class="col_heading level0 col3" >R2</th>        <th class="col_heading level0 col4" >RMSLE</th>        <th class="col_heading level0 col5" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row0_col0" class="data row0 col0" >80.0278</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row0_col1" class="data row0 col1" >9834.5547</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row0_col2" class="data row0 col2" >99.1693</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row0_col3" class="data row0 col3" >0.5848</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row0_col4" class="data row0 col4" >0.1940</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row0_col5" class="data row0 col5" >0.1637</td>
#             </tr>
#             <tr>
#                         <th id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row1_col0" class="data row1 col0" >73.5451</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row1_col1" class="data row1 col1" >8009.9602</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row1_col2" class="data row1 col2" >89.4984</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row1_col3" class="data row1 col3" >0.7504</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row1_col4" class="data row1 col4" >0.1449</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row1_col5" class="data row1 col5" >0.1318</td>
#             </tr>
#             <tr>
#                         <th id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row2_col0" class="data row2 col0" >85.5521</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row2_col1" class="data row2 col1" >12642.6598</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row2_col2" class="data row2 col2" >112.4396</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row2_col3" class="data row2 col3" >0.3431</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row2_col4" class="data row2 col4" >0.1801</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row2_col5" class="data row2 col5" >0.1499</td>
#             </tr>
#             <tr>
#                         <th id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row3_col0" class="data row3 col0" >55.1215</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row3_col1" class="data row3 col1" >3989.2992</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row3_col2" class="data row3 col2" >63.1609</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row3_col3" class="data row3 col3" >0.7832</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row3_col4" class="data row3 col4" >0.1124</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row3_col5" class="data row3 col5" >0.1075</td>
#             </tr>
#             <tr>
#                         <th id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row4_col0" class="data row4 col0" >107.6736</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row4_col1" class="data row4 col1" >16973.0994</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row4_col2" class="data row4 col2" >130.2808</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row4_col3" class="data row4 col3" >0.4138</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row4_col4" class="data row4 col4" >0.2228</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row4_col5" class="data row4 col5" >0.1977</td>
#             </tr>
#             <tr>
#                         <th id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row5_col0" class="data row5 col0" >96.0208</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row5_col1" class="data row5 col1" >12485.1740</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row5_col2" class="data row5 col2" >111.7371</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row5_col3" class="data row5 col3" >0.5042</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row5_col4" class="data row5 col4" >0.1736</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row5_col5" class="data row5 col5" >0.1549</td>
#             </tr>
#             <tr>
#                         <th id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row6_col0" class="data row6 col0" >58.9219</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row6_col1" class="data row6 col1" >5019.8020</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row6_col2" class="data row6 col2" >70.8506</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row6_col3" class="data row6 col3" >0.5079</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row6_col4" class="data row6 col4" >0.1290</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row6_col5" class="data row6 col5" >0.0969</td>
#             </tr>
#             <tr>
#                         <th id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row7_col0" class="data row7 col0" >120.2656</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row7_col1" class="data row7 col1" >35395.5217</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row7_col2" class="data row7 col2" >188.1370</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row7_col3" class="data row7 col3" >-0.0164</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row7_col4" class="data row7 col4" >0.4127</td>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row7_col5" class="data row7 col5" >0.3368</td>
#             </tr>
#             <tr>
#                         <th id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_cfb8d648_3022_11eb_a8b4_e0b9a5834b53row8_col0" class="data row

# %%
evaluate_model(tuned_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
predict_model(tuned_model);
# Out:
# <style  type="text/css" >
# </style><table id="T_d8f0c13a_3022_11eb_a8b4_e0b9a5834b53" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d8f0c13a_3022_11eb_a8b4_e0b9a5834b53level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d8f0c13a_3022_11eb_a8b4_e0b9a5834b53row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#                         <td id="T_d8f0c13a_3022_11eb_a8b4_e0b9a5834b53row0_col1" class="data row0 col1" >96.5839</td>
#                         <td id="T_d8f0c13a_3022_11eb_a8b4_e0b9a5834b53row0_col2" class="data row0 col2" >15629.6043</td>
#                         <td id="T_d8f0c13a_3022_11eb_a8b4_e0b9a5834b53row0_col3" class="data row0 col3" >125.0184</td>
#                         <td id="T_d8f0c13a_3022_11eb_a8b4_e0b9a5834b53row0_col4" class="data row0 col4" >0.5450</td>
#                         <td id="T_d8f0c13a_3022_11eb_a8b4_e0b9a5834b53row0_col5" class="data row0 col5" >0.2076</td>
#                         <td id="T_d8f0c13a_3022_11eb_a8b4_e0b9a5834b53row0_col6" class="data row0 col6" >0.1721</td>
#             </tr>
#     </tbody></table>

# %%
final_model = finalize_model(tuned_model)
print(final_model)
predict_model(final_model);
# Out:
# RandomForestRegressor(bootstrap=True, ccp_alpha=0.0, criterion='mae',
#                       max_depth=9, max_features=1.0, max_leaf_nodes=None,
#                       max_samples=None, min_impurity_decrease=0.0001,
#                       min_impurity_split=None, min_samples_leaf=4,
#                       min_samples_split=7, min_weight_fraction_leaf=0.0,
#                       n_estimators=80, n_jobs=-1, oob_score=False,
#                       random_state=2803, verbose=0, warm_start=False)
# <style  type="text/css" >
# </style><table id="T_dac7ecea_3022_11eb_a8b4_e0b9a5834b53" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >MAE</th>        <th class="col_heading level0 col2" >MSE</th>        <th class="col_heading level0 col3" >RMSE</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >RMSLE</th>        <th class="col_heading level0 col6" >MAPE</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_dac7ecea_3022_11eb_a8b4_e0b9a5834b53level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_dac7ecea_3022_11eb_a8b4_e0b9a5834b53row0_col0" class="data row0 col0" >Random Forest Regressor</td>
#                         <td id="T_dac7ecea_3022_11eb_a8b4_e0b9a5834b53row0_col1" class="data row0 col1" >66.9715</td>
#                         <td id="T_dac7ecea_3022_11eb_a8b4_e0b9a5834b53row0_col2" class="data row0 col2" >7597.9944</td>
#                         <td id="T_dac7ecea_3022_11eb_a8b4_e0b9a5834b53row0_col3" class="data row0 col3" >87.1665</td>
#                         <td id="T_dac7ecea_3022_11eb_a8b4_e0b9a5834b53row0_col4" class="data row0 col4" >0.7788</td>
#                         <td id="T_dac7ecea_3022_11eb_a8b4_e0b9a5834b53row0_col5" class="data row0 col5" >0.1447</td>
#                         <td id="T_dac7ecea_3022_11eb_a8b4_e0b9a5834b53row0_col6" class="data row0 col6" >0.1168</td>
#             </tr>
#     </tbody></table>

# %%
save_model(final_model,'Final Model 12112020')
# Out:
# Transformation Pipeline and Model Succesfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=['contract',
#                                                              'district', 'floor',
#                                                              'property_type',
#                                                              'building_year',
#                                                              'air_conditioning'],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[], ml_usecase='regression',
#                                        numerical_features=['locals', 'surface'],
#                                        target='price', time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical...
#                                 boosting_type='gbdt', class_weight=None,
#                                 colsample_bytree=1.0, feature_fraction=1.0,
#                                 importance_type='split', learning_rate=0.072,
#                                 max_depth=-1, min_child_samples=35,
#                                 min_child_weight=0.001, min_split_gain=0.9,
#                                 n_estimators=140, n_jobs=-1, num_leaves=90,
#                                 objective=None, random_state=6234, reg_alpha=4,
#                                 reg_lambda=0.3, silent=True, subsample=1.0,
#                                 subsample_for_bin=200000, subsample_freq=0)]],
#           verbose=False),
#  'Final Model 12112020.pkl')

# %%
predictions = predict_model(final_model, data=dati.drop(columns=['announce_link', 'Unnamed: 0.1']))

# %%
predictions.reset_index(inplace=True)

# %%
predictions = predictions[predictions['price']<3000]
plt = predictions[['price', 'Label']].plot(figsize=(25,10))
fig = plt.get_figure()
fig.savefig("risultato_pycaret.png")
fig.savefig("risultato_pycaret.svg")

# %%
import scipy
scipy.stats.pearsonr(predictions['price'], predictions['Label'])[0]
# Out:
# 0.8800700062829528

# %%
(predictions['price'] - predictions['Label']).plot(figsize=(25,10))
# Out:
# <AxesSubplot:>

# %%
predictions['links'] = dati.reset_index()['announce_link']

# %%
predictions.to_csv('predictions_PYCARET.csv')
